# %%
# gradient descent concept using named variables

'''
alpha variable is used to avoid Divergence, for when our inputs are too high, causing our prediction
values to have bigger and bigger magnitde after each iteration.
This problem is solved by having our weight mutiplied by alpha on each learning step
'''

import numpy as np

weight = 0.5
goal_prediction = 0.8
input = 2.0


alpha = 0.1

for i in range(20):
    
    pred = input * weight
    error = (pred - goal_prediction) ** 2
    
    derivative = ( input * (pred - goal_prediction) )
    weight = weight - (alpha * derivative)
    
    print("Error: " + str(error) + " Prediction:" + str(pred))
# Out:
# Error: 0.03999999999999998 Prediction:1.0
# Error: 0.0144 Prediction:0.92
# Error: 0.005183999999999993 Prediction:0.872
# Error: 0.0018662400000000014 Prediction:0.8432000000000001
# Error: 0.0006718464000000028 Prediction:0.8259200000000001
# Error: 0.00024186470400000033 Prediction:0.815552
# Error: 8.70712934399997e-05 Prediction:0.8093312
# Error: 3.134566563839939e-05 Prediction:0.80559872
# Error: 1.1284439629823931e-05 Prediction:0.803359232
# Error: 4.062398266736526e-06 Prediction:0.8020155392
# Error: 1.4624633760252567e-06 Prediction:0.8012093235200001
# Error: 5.264868153690924e-07 Prediction:0.8007255941120001
# Error: 1.8953525353291194e-07 Prediction:0.8004353564672001
# Error: 6.82326912718715e-08 Prediction:0.8002612138803201
# Error: 2.456376885786678e-08 Prediction:0.8001567283281921
# Error: 8.842956788836216e-09 Prediction:0.8000940369969153
# Error: 3.1834644439835434e-09 Prediction:0.8000564221981492
# ...

# %%
# gradient descent with multiple inputs
# 3 inputs on this example

weights = [0.1, 0.2, 0.3]

def w_sum(a,b):
    
    assert(len(a) == len(b))
    
    output = 0
    
    for i in range(0, len(a)):
        output += a[i] * b[i]
        
    return output

def elem_multip(number, vector):
    
    output = [0, 0, 0]
    
    assert(len(output) == len(vector))
    
    for i in range(0, len(output)):
        output[i] = number * vector[i]
    
    return output
        
def neural_network(input, weights):
    
    pred = w_sum(input, weights)
    
    return pred

toes = [8.5, 9.5, 9.9, 9.0]
wlrec = [0.9, 0.8, 0.8, 0.9]
nfans = [1.2, 1.3, 0.5, 1.0]

# this is the goal_pred from other examples
win_or_lose_binary = [1, 1, 0, 1]


# representing only one input. (simulating data for the first match of a season)
true = win_or_lose_binary[0]
input = [ toes[0], wlrec[0], nfans[0] ]

# calculating prediction
pred = neural_network(input, weights)

error = (pred - true) ** 2

delta = (pred - true)

weights_delta = elem_multip(delta, weights)

alpha = 0.01

for i in range(len(weights)):
    weights[i] -= alpha * weights_delta[i]

# %%
# debugging iterations of learning
# checking each iteration values for delta_weights and its corresponding weight adjustment

def neural_network(input, weights):
    
    out = 0
    
    for i in range(0, len(weights)):
        out += input[i] * weights[i]
        
    return out

def scalar_mult(scalar, vector):
    
    out = [0, 0, 0]
    
    for i in range(0, len(vector)):
        out[i] = scalar * vector[i]
        
    return out

toes = [8.5, 9.5, 9.9, 9.0]
wlrec = [0.65, 0.8, 0.8, 0.9]
nfans = [1.2, 1.3, 0.5, 1.0]

win_or_lose_binary = [1, 1, 0, 1]
true = win_or_lose_binary[0]

alpha = 0.01

weights = [0.1, 0.2, -.1]

input = [toes[0], wlrec[0], nfans[0]]

for i in range(10):

    pred = neural_network(input, weights)

    error = (pred - true) ** 2

    delta = pred - true

    delta_weight = scalar_mult(delta, input)
    
    print("Iteration: " + str(i+1))
    print("Pred: " + str(pred))
    print("Error: " + str(error))
    print("Delta: " + str(delta))
    print("Weights: " + str(weights))
    print("Delta Weights: " + str(delta_weight))
    
    for i in range(len(weights)):
        weights[i] = weights[i] - (alpha * delta_weight[i])
# Out:
# Iteration: 1
# Pred: 0.8600000000000001
# Error: 0.01959999999999997
# Delta: -0.1399999999999999
# Weights: [0.1, 0.2, -0.1]
# Delta Weights: [-1.189999999999999, -0.09099999999999994, -0.16799999999999987]
# Iteration: 2
# Pred: 0.9637574999999999
# Error: 0.0013135188062500048
# Delta: -0.036242500000000066
# Weights: [0.1119, 0.20091, -0.09832]
# Delta Weights: [-0.30806125000000056, -0.023557625000000044, -0.04349100000000008]
# Iteration: 3
# Pred: 0.9906177228125002
# Error: 8.802712522307997e-05
# Delta: -0.009382277187499843
# Weights: [0.11498061250000001, 0.20114557625, -0.09788509000000001]
# Delta Weights: [-0.07974935609374867, -0.006098480171874899, -0.011258732624999811]
# Iteration: 4
# Pred: 0.997571162993086
# Error: 5.899249206154892e-06
# Delta: -0.0024288370069139864
# Weights: [0.1157781060609375, 0.20120656105171877, -0.09777250267375001]
# Delta Weights: [-0.020645114558768884, -0.0015787440544940913, -0.0029146044082967834]
# Iteration: 5
# ...

# %%
# gradient descent with one input and multiple outputs

weights = [0.3, 0.2, 0.9]

def neural_network(input, weights):
    
    output = scalar_mult(input, weights)
    
    return output
    
def scalar_mult(scalar, vector):
    
    out = [0, 0, 0]
    
    for i in range(0, len(vector)):
        out[i] = scalar * vector[i]
        
    return out

# inputs
wlrec = [0.9, 1.0, 1.0, 0.9]

# yhat
hurt = [0.1, 0.0, 0.0, 0.1]
win = [1, 1, 0, 1]
sad = [0.1, 0.0, 0.1, 0.2]

input = wlrec[0]

# goal_pred or more commonly known as yhat
true = [hurt[0], win[0], sad[0]]

pred = neural_network(input, weights)

error = [0, 0, 0]
delta =[0, 0, 0]

for i in range(len(true)):
    error = (pred[i] - true[i]) ** 2
    delta = pred[i] - true[i]
    
delta_weights = scalar_mult(input, weights)

alpha = 0.01

for i in range(len(weights)):
    weights[i] = weights[i] - (alpha * delta_weights[i])

# %%
# gradient descente with multiple inputs and multiple outputs

import numpy as np

            # toes, wins,nfans
weights = [ [0.1, 0.1, 0.3], # hurt?
            [0.1, 0.2, 0.0], # win?
            [0.0, 1.3, 0,1]] # sad?

def neural_network(input, vector):
    
    pred = vec_mat_mult(input, vector)
    
    return pred

def w_sum(vectorA, vectorB):
    
    output = 0
    
    for i in range(len(vectorA)):
        output += vectorA[i] * vectorB[i]
        
    return output

def vec_mat_mult(vector, matrix):
    
    assert(len(vector) == len(matrix))
    
    output = [0, 0, 0]
    
    for i in range(len(vector)):
        output[i] = w_sum(vector,matrix[i])
        
    return output

def outer_prod(vecA, vecB):
    
    out = np.zeros( (len(vecA),len(vecB) ) )
    
    for i in range(len(vecA)):
        for j in range(len(vecB)):
            out[i][j] = vecA[i] * vecB[j]
    
    return out

toes = [8.5, 9.5, 9.9, 9.0]
wlrec = [0.65,0.8, 0.8, 0.9]
nfans = [1.2, 1.3, 0.5, 1.0]

hurt = [0.1, 0.0, 0.0, 0.1]
win = [1, 1, 0, 1]
sad = [0.1, 0.0, 0.1, 0.2]
    
alpha = 0.01

input = [toes[0], wlrec[0], nfans[0]]
true = [hurt[0], win[0], sad[0]]

error = [0, 0, 0]
delta = [0, 0, 0]

pred = neural_network(input, weights)

for i in range(len(pred)):
    error[i] = (pred[i] - true[i]) ** 2
    delta[i] = (pred[i] - true[i])
    
delta_weights = outer_prod(input, delta)
                
for i in range (len(weights)):
    for j in range (len(delta_weights)):
        weights[i][j] -= alpha * delta_weights[i][j]
