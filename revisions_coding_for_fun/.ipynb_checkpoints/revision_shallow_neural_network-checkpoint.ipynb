# %%
'''
just having some fun trying to code a shallow neural network as fast as possible
multiple inputs and multiple inputs neural network
this code will be using numpy dot function instead of manually creating functions to retrive dot of 2 vectors
''' 

import numpy as np

weights = np.array ( [[0.1, 0.1, 0.3], [0.1, 0.2, 0.0], [0.0, 1.3, 0.1]])

def neural_network(input, weights):
    
    '''
    weights must be transversed as input is 1-D and and weights is 2-D
    '''
    pred = input.dot(weights.T)

    return pred

def vect_mult(input, weights):
    
    output = np.zeros((len(input),1))
    
    for i in range(len(input)):
        output[i] = w_sum(input,weights[i])
        
    return output

def w_sum(a,b):
    
    output = 0
    for i in range(0, len(a)):
        output += a[i] * b[i]
    
    return output
            
def outer(input, delta):
    
    output = np.zeros((len(input),len(delta)))
    
    for i in range(len(input)):
        for j in range(len(delta)):
            output[i][j] = input[i] * delta[j]
    
    return output

toes = np.array([8.5, 9.5, 9.9, 9.0])
wlrec = np.array([0.65,0.8, 0.8, 0.9])
nfans = np.array([1.2, 1.3, 0.5, 1.0])

hurt = np.array([0.1, 0.0, 0.0, 0.1])
win = np.array([1, 1, 0, 1])
sad = np.array([0.1, 0.0, 0.1, 0.2])

input = np.array( [toes[0], wlrec[0], nfans[0] ])

true = np.array([hurt[0], win[0], sad[0]])

pred = neural_network(input, weights)

error = np.array([0, 0, 0], float)
delta = np.array([0, 0, 0], float)

delta_weights = np.zeros((len(input),len(delta)))

for i in range(len(pred)):
    error[i] = (pred[i] - true[i]) ** 2
    delta[i] = pred[i] - true[i]
    
delta_weights = outer(input, delta)

alpha = 0.01

for i in range(len(delta_weights)):
    for j in range(len(weights)):
        weights[i][j] = weights[i][j] - (alpha * delta_weights[i][j])


    
print(delta_weights)
print(weights)
# Out:
# [[ 9.9875  -0.17     7.3525 ]
#  [ 0.76375 -0.013    0.56225]
#  [ 1.41    -0.024    1.038  ]]
# [[ 1.25000e-04  1.01700e-01  2.26475e-01]
#  [ 9.23625e-02  2.00130e-01 -5.62250e-03]
#  [-1.41000e-02  1.30024e+00  8.96200e-02]]

# %%
# just having some fun trying to code a shallow neural network as fast as possible

import numpy as np

weights = [ [0.1, 0.1, 0.3], # hurt?
            [0.1, 0.2, 0.0], # win?
            [0.0, 1.3, 0.1]] # sad?


def neural_network(input, weights):
    
    pred = vec_mat_mult(input, weights)
    
    return pred

def vec_mat_mult(vector, matrix):
    
    assert(len(vector) == len(matrix))
    
    output = [0, 0, 0]
    
    for i in range(len(output)):
        output[i] = w_sum(vector, matrix[i])
    
    return output

def w_sum(a, b):
    
    output = 0
    
    for i in range(len(a)):
        output += a[i] * b[i]
    
    return output
        
def outer_product(input, delta):
    
    delta_weights = np.zeros( (len(input), len(delta)) )
    
    for i in range(len(input)):
        for j in range(len(delta)):
            delta_weights[i][j] = input[i] * delta[j]
    
    return delta_weights
        

toes = [8.5, 9.5, 9.9, 9.0]
wlrec = [0.65,0.8, 0.8, 0.9]
nfans = [1.2, 1.3, 0.5, 1.0]

hurt = [0.1, 0.0, 0.0, 0.1]
win = [1, 1, 0, 1]
sad = [0.1, 0.0, 0.1, 0.2]

input = [toes[0], wlrec[0], nfans[0]]

true = [hurt[0], win[0], sad[0]]

pred = neural_network(input, weights)
    
error = [0, 0, 0]
delta = [0, 0, 0]

for i in range(len(pred)):
    error[i] = (pred[i] - true[i]) ** 2
    delta[i] = pred[i] - true[i]

delta_weights = outer_product(input, delta)

alpha = 0.01

for i in range(len(delta_weights)):
    for j in range(len(weights)):
        weights[i][j] -= delta_weights[i][j] * alpha
